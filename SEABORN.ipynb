# %% [markdown]
# # SEABORN

# %%
import seaborn
seaborn.__version__
# Out:
# '0.13.2'

# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ## SEABORN DATASETS

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# ## IMPORT SEABORN DATASET

# %%
df = sns.load_dataset('penguins')
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.species.value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
df.island.value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
df.sex.value_counts()
# Out:
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %% [markdown]
# ## SCATTER PLOT

# %%
sns.scatterplot(data = df, x = 'flipper_length_mm',y = 'body_mass_g')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %% [markdown]
# **FROM THIS WE CAN SAY THAT FLIPPER LENGTH INCREASES, THE BODY MASS ALSO INCREASES**

# %%
sns.scatterplot(data = df, x = 'flipper_length_mm',y = 'body_mass_g',hue = 'island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data = df,x = 'flipper_length_mm',y = 'body_mass_g',hue = 'sex')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %% [markdown]
# **STYLING THEMES**
# * white
# * dark
# * whitegrid
# * darkgrid
# * ticks

# %%
sns.set_style('white')
sns.scatterplot(data = df,x = 'flipper_length_mm',y='body_mass_g',hue='sex')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set_style('white')
sns.scatterplot(data = df,x = 'flipper_length_mm',y='body_mass_g',hue='sex')
sns.despine() # just removing top and right edges ;
# try left = True, bottom = True

# %% [markdown]
# **CONTEXTS**
# *IT CAN ALTER THE SIZE OF LABELS,LINES AND OTHER ELEMENT OF PLOTS*
# * Poster
# * paper
# * notebook
# * talk

# %%
sns.set_style('white')
sns.set_context('notebook')
sns.scatterplot(data = df,x = 'flipper_length_mm',y='body_mass_g',hue='sex')
sns.despine(left = True,bottom = True)

# %%
sns.scatterplot(data =df,x = 'species',y = 'body_mass_g',hue = 'island',style = 'sex')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.scatterplot(data =df,x = 'species',y = 'body_mass_g',hue = 'island',style = 'sex',alpha = 0.5)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ## STRIP PLOT

# %%
sns.stripplot(data = df,x = 'species',y = 'body_mass_g',hue = 'island')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.stripplot(data = df,x = 'species',y = 'body_mass_g',hue = 'island',jitter = True)
# this gonna separate datapoints based on hue
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.stripplot(data = df,x = 'species',y = 'body_mass_g',hue = 'island',dodge = True)
# this gonna separate datapoints based on hue
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ## SWARM PLOT

# %%
sns.swarmplot(data = df,x = 'species',y='body_mass_g',hue = 'island')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.set_context('talk')
sns.despine()
sns.swarmplot(data = df,x = 'species',y='body_mass_g',hue = 'island')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ## HISTOGRAM

# %%
sns.set_context('notebook')
sns.histplot(data = df,x = 'body_mass_g')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data = df,x = 'body_mass_g',hue = 'sex',multiple='stack')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# ## REGRESSION PLOT

# %%
sns.regplot(data = df,x = 'body_mass_g',y = 'flipper_length_mm',color = 'green')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# ## LINE PLOT

# %%
sns.lineplot(data = df,x = 'body_mass_g',y = 'flipper_length_mm')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.set_style('whitegrid')
sns.lineplot(data = df,x = 'body_mass_g',y = 'flipper_length_mm')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.set_style('whitegrid')
sns.lineplot(data = df,x = 'body_mass_g',y = 'flipper_length_mm',hue = 'sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.set_style('whitegrid')
sns.lineplot(data = df,x = 'body_mass_g',y = 'flipper_length_mm',hue = 'island',style = 'sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# ## JOINT PLOT

# %%
sns.jointplot(data = df,x = 'body_mass_g',y = 'flipper_length_mm')
# histogram says the density of distribution

# %%
sns.jointplot(data = df,x = 'body_mass_g',y = 'flipper_length_mm',hue = 'sex')

# %%
sns.jointplot(data = df,x = 'body_mass_g',y = 'flipper_length_mm',hue = 'sex',kind = 'kde')
# kde says the concentration

# %%
sns.jointplot(data = df,x = 'body_mass_g',y = 'flipper_length_mm',hue = 'island',kind = 'scatter')

# %%
sns.jointplot(data = df,x = 'body_mass_g',y = 'flipper_length_mm',kind = 'reg')

# %% [markdown]
# ## BAR PLOT

# %%
sns.barplot(data = df,x = 'species',y = 'body_mass_g',hue = 'sex',palette = ['pink','blue'])
# says the average distribution of sex
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(data = df,x = 'species',y = 'body_mass_g',hue = 'sex',palette = ['pink','blue'],estimator='sum')
# says the sum
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(data = df,x = 'species',y = 'body_mass_g',hue = 'sex',palette = ['pink','blue'],estimator='median')
# try for sta, var
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ## COUNT PLOT

# %%
sns.countplot(data = df, x = 'species',hue = 'island')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# ## BOX PLOT

# %%
sns.boxplot(data = df,x = 'species',y = 'body_mass_g',hue = 'sex')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ## VIOLIN PLOT

# %%
sns.violinplot(data = df,x = 'species',y = 'body_mass_g')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.violinplot(data = df,x = 'species',y = 'body_mass_g',hue = 'sex')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.violinplot(data = df,x = 'species',y = 'body_mass_g',hue = 'sex',split = True)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# * Width of the violin : Density of the data at different values
# * middle line : Median
# * Thick bar : Quartile range

# %%
sns.violinplot(data = df,x = 'species',y = 'body_mass_g')
sns.swarmplot(data = df,x = 'species',y = 'body_mass_g',color = 'black',size = 3)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ## KERNAL DENSITY ESTIMATOR PLOT

# %%
# Used for estimating the pdf of continuous data
# Smooth version of histogram
# Helps to see the concentration (peak) and its spreads

# %%
sns.kdeplot(data = df,x = 'body_mass_g',hue = 'island',fill = True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# ## HEATMAP

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# Allows only numeric data
cols = ['bill_length_mm','bill_depth_mm','flipper_length_mm','body_mass_g']

# %%
df[cols].corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(df[cols].corr(),annot = True,cmap ='coolwarm')
# Out:
# <Axes: >

# %%
sns.heatmap(df[cols].corr(),annot = True,vmin = -0.2,vmax = 1.5)
# Out:
# <Axes: >

# %%
sns.heatmap(df[cols].corr(),annot = True,vmin = -0.2,vmax = 1.5,linewidth = 5)
# Out:
# <Axes: >
